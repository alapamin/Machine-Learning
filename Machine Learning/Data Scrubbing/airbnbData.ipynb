# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("listings.csv")

# %%
sns.pairplot(df,vars=['price','number_of_reviews','availability_365'])
#plotted three chosen variables against each other

# %%
df_corr=df.corr()

# %%
sns.heatmap(df_corr,annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#      id                                              name  host_id host_name  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central     2217       Ian
# 1  2695                Prenzlauer Berg close to Mauerpark     2986   Michael
# 2  3176                   Fabulous Flat in great Location     3718    Britta
# 3  3309                 BerlinSpot Schöneberg near KaDeWe     4108      Jana
# 4  7071                  BrightRoom with sunny greenview!    17391    Bright
#
#       neighbourhood_group             neighbourhood   latitude  longitude  \
# 0                   Mitte           Brunnenstr. Süd  52.534537  13.402557
# 1                  Pankow  Prenzlauer Berg Nordwest  52.548513  13.404553
# 2                  Pankow   Prenzlauer Berg Südwest  52.534996  13.417579
# 3  Tempelhof - Schöneberg           Schöneberg-Nord  52.498855  13.349065
# 4                  Pankow            Helmholtzplatz  52.543157  13.415091
#
# ...

# %%
df.tail(n=5)
# Out:
#              id                                               name    host_id  \
# 22547  29856708       Cozy Apartment right in the center of Berlin   87555909
# 22548  29857108             Altbau/ Schöneberger Kiez / Schlafsofa   67537363
# 22549  29864272   Artists loft with garden in the center of Berlin    3146923
# 22550  29866805              Room for two with private shower / WC   36961901
# 22551  29867352  Sunny, modern and cozy flat in Berlin Neukölln :)  177464875
#
#         host_name     neighbourhood_group            neighbourhood   latitude  \
# 22547     Ulisses                   Mitte          Brunnenstr. Süd  52.533865
# 22548        Jörg  Tempelhof - Schöneberg          Schöneberg-Nord  52.496211
# 22549      Martin                  Pankow  Prenzlauer Berg Südwest  52.531800
# 22550  Arte Luise                   Mitte           Alexanderplatz  52.520802
# 22551   Sebastian                Neukölln        Schillerpromenade  52.473762
#
# ...

# %%
del df['latitude']
del df['longitude']

# %%
df.head(n=5)
# Out:
#      id                                              name  host_id host_name  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central     2217       Ian
# 1  2695                Prenzlauer Berg close to Mauerpark     2986   Michael
# 2  3176                   Fabulous Flat in great Location     3718    Britta
# 3  3309                 BerlinSpot Schöneberg near KaDeWe     4108      Jana
# 4  7071                  BrightRoom with sunny greenview!    17391    Bright
#
#       neighbourhood_group             neighbourhood        room_type  price  \
# 0                   Mitte           Brunnenstr. Süd  Entire home/apt     60
# 1                  Pankow  Prenzlauer Berg Nordwest     Private room     17
# 2                  Pankow   Prenzlauer Berg Südwest  Entire home/apt     90
# 3  Tempelhof - Schöneberg           Schöneberg-Nord     Private room     26
# 4                  Pankow            Helmholtzplatz     Private room     42
#
# ...

# %%
df = pd.get_dummies(df, columns = ['neighbourhood_group','neighbourhood'], drop_first = True)

# %%
df.head(n=1)
# Out:
#      id                                              name  host_id host_name  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central     2217       Ian
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt     60               4                118  2018-10-28
#
#    reviews_per_month  ...  neighbourhood_West 3  neighbourhood_West 4  \
# 0               3.76  ...                     0                     0
#
#    neighbourhood_West 5  neighbourhood_Westend  \
# 0                     0                      0
#
#    neighbourhood_Wiesbadener Straße  neighbourhood_Wilhelmstadt  \
# 0                                 0                           0
#
#    neighbourhood_Zehlendorf  Nord  neighbourhood_Zehlendorf  Südwest  \
# 0                               0                                  0
#
#    neighbourhood_nördliche Luisenstadt  neighbourhood_südliche Luisenstadt
# ...

# %%
df.isnull().sum() #inspecting missing values.
# Out:
# id                                      0
# name                                   59
# host_id                                 0
# host_name                              26
# room_type                               0
#                                        ..
# neighbourhood_Wilhelmstadt              0
# neighbourhood_Zehlendorf  Nord          0
# neighbourhood_Zehlendorf  Südwest       0
# neighbourhood_nördliche Luisenstadt     0
# neighbourhood_südliche Luisenstadt      0
# Length: 158, dtype: int64

# %%
#df['reviews_per_month'].fillna(df['reviews_per_month'].mode(),inplace=True)
#Fill with most occuring number

# %%
#df['reviews_per_month'].fillna(0)
#Fill with 0s

# %%
df.dropna(axis = 0, how = 'any', thresh = None, subset = None, inplace = True)
#You can either replace missing or null values with the mean, mode, 0, etc.
#Or you drop the column if the above is not possible or if the variable is not needed.
